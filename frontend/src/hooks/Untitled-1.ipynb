# %%
import json

# Load English translations
with open('c:/Users/chereto/Desktop/eoty-platform/frontend/src/i18n/locales/en/translation.json', 'r', encoding='utf-8') as f:
    en_data = json.load(f)

# Load Amharic translations
with open('c:/Users/chereto/Desktop/eoty-platform/frontend/src/i18n/locales/am/translation.json', 'r', encoding='utf-8') as f:
    am_data = json.load(f)

# Define the new structure for teacher_resources
teacher_resources_en = {
    "title": "Resource Library",
    "subtitle": "Manage and distribute educational content to your members",
    "back_dashboard": "Back to Dashboard",
    "new_resource": "New Resource",
    "stats": {
      "total": "Total Resources",
      "storage": "Storage Used",
      "this_month": "This Month"
    },
    "tabs": {
      "upload": "Upload Center",
      "browse": "Browse Library"
    },
    "upload_center": {
      "title": "Where would you like to upload?",
      "subtitle": "Choose the visibility scope for your new resource",
      "platform": {
        "title": "Platform Wide",
        "description": "Share resources with the entire Orthodox community worldwide.",
        "badge": "Admin Access"
      },
      "chapter": {
        "title": "Chapter Only",
        "description": "Exclusive content for members of your local chapter.",
        "badge": "Most Common"
      },
      "course": {
        "title": "Course Specific",
        "description": "Attach materials directly to your courses and lessons.",
        "badge": "Targeted"
      }
    },
    "browse": {
      "search_placeholder": "Search by name, type, or tag...",
      "scope": {
        "chapter": "Chapter Resources",
        "platform": "Platform Resources"
      },
      "loading": "Loading your library...",
      "empty": {
        "title": "No resources found",
        "subtitle": "Get started by uploading your first resource",
        "btn": "Upload Resource"
      },
      "uncategorized": "Uncategorized",
      "no_description": "No description provided",
      "general": "General",
      "download": "Download"
    },
    "filters": {
        "all": "All Resources",
        "platform_wide": "Platform Wide",
        "chapter_wide": "Chapter Wide",
        "course_specific": "Course Specific",
        "mine": "My Uploads",
        "category": "Category",
        "language": "Language",
        "type": "File Type",
        "sort_newest": "Newest First",
        "sort_oldest": "Oldest First",
        "sort_title": "Title (A-Z)",
        "page_size": "{{count}} per page",
        "reset": "Reset Filters"
    }
}

teacher_resources_am = {
    "title": "የመረጃ ቤተ-መጽሐፍት",
    "subtitle": "ትምህርታዊ ይዘቶችን ያስተዳድሩ እና ለአባላት ያሰራጩ",
    "back_dashboard": "ወደ ዳሽቦርድ ተመለስ",
    "new_resource": "አዲስ መረጃ",
    "stats": {
      "total": "ጠቅላላ መረጃዎች",
      "storage": "ጥቅም ላይ የዋለ ማከማቻ",
      "this_month": "በዚህ ወር"
    },
    "tabs": {
      "upload": "የመስቀያ ማዕከል",
      "browse": "ቤተ-መጽሐፍቱን ያስሱ"
    },
    "upload_center": {
      "title": "የት መስቀል ይፈልጋሉ?",
      "subtitle": "ለአዲሱ መረጃዎ የታይነት ወሰን ይምረጡ",
      "platform": {
        "title": "በመድረኩ ደረጃ",
        "description": "መረጃዎችን በዓለም ዙሪያ ካሉ የኦርቶዶክስ ማህበረሰብ ጋር ያጋሩ።",
        "badge": "የአስተዳዳሪ መዳረሻ"
      },
      "chapter": {
        "title": "በማዕከል ደረጃ",
        "description": "ለአካባቢዎ ማዕከል አባላት ብቻ የሚሆን ይዘት።",
        "badge": "በጣም የተለመደ"
      },
      "course": {
        "title": "ለኮርስ ብቻ",
        "description": "ትምህርታዊ ቁሳቁሶችን በቀጥታ ከኮርሶችዎ እና ትምህርቶችዎ ጋር ያያይዙ።",
        "badge": "የታለመ"
      }
    },
    "browse": {
      "search_placeholder": "በስም፣ በዓይነት ወይም በታግ ይፈልጉ...",
      "scope": {
        "chapter": "የማዕከል መረጃዎች",
        "platform": "የመድረክ መረጃዎች"
      },
      "loading": "ቤተ-መጽሐፍቱን በመጫን ላይ...",
      "empty": {
        "title": "ምንም መረጃዎች አልተገኙም",
        "subtitle": "የመጀመሪያውን መረጃ በመስቀል ይጀምሩ",
        "btn": "መረጃ ይስቀሉ"
      },
      "uncategorized": "ያልተመደበ",
      "no_description": "ምንም መግለጫ አልተሰጠም",
      "general": "አጠቃላይ",
      "download": "አውርድ"
    },
    "filters": {
        "all": "ሁሉም መረጃዎች",
        "platform_wide": "በመድረኩ ደረጃ",
        "chapter_wide": "በማዕከል ደረጃ",
        "course_specific": "ለኮርስ ብቻ",
        "mine": "የእኔ ብቻ",
        "category": "ምድብ",
        "language": "ቋንቋ",
        "type": "የፋይል ዓይነት",
        "sort_newest": "አዲስ",
        "sort_oldest": "የቆየ",
        "sort_title": "ርዕስ (A-Z)",
        "page_size": "{{count}} በገጽ",
        "reset": "ማጣሪያዎችን ዳግም አስጀምር"
    }
}

# Update English
en_data['teacher_resources'] = teacher_resources_en

# Update Amharic
am_data['teacher_resources'] = teacher_resources_am

# Save English
with open('c:/Users/chereto/Desktop/eoty-platform/frontend/src/i18n/locales/en/translation.json', 'w', encoding='utf-8') as f:
    json.dump(en_data, f, indent=2, ensure_ascii=False)

# Save Amharic
with open('c:/Users/chereto/Desktop/eoty-platform/frontend/src/i18n/locales/am/translation.json', 'w', encoding='utf-8') as f:
    json.dump(am_data, f, indent=2, ensure_ascii=False)
